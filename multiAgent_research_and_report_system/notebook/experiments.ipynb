# %%
import os
import sys
# sys.path.append(os.path.dirname(os.path.dirname("..")))
# os.path.dirname(os.path.dirname(os.path.join("..")))
path  = os.path.dirname(os.path.dirname(os.path.join(os.path.abspath(os.path.curdir))))
path
sys.path.append(path)
sys.path.append(os.path.join(path,"graph"))

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from graph.research_team.research_team import getResearchTeamGraph
#       3 getResearchTeamGraph()
#
# File c:\Users\muham\Desktop\langgraph_project\multiAgent_research_and_report_system\graph\research_team\research_team.py:1
# ----> 1 from multiAgent_research_and_report_system.src.supervisor import make_supervisor_node
#       2 from multiAgent_research_and_report_system.utils.model_loader import model_loader
#       3 from finance_research_node import finance_research_node
#
# ModuleNotFoundError: No module named 'multiAgent_research_and_report_system'

# %%
from multiAgent_research_and_report_system.graph.research_team.research_team import getResearchTeamGraph

img = getResearchTeamGraph()
img.invoke({"messages": ["does indian gdp is becoming better?"]})
# Out:
# {'messages': [HumanMessage(content='does indian gdp is becoming better?', additional_kwargs={}, response_metadata={}, id='43856590-5cf5-4375-8b1f-0f0f8c94ca06'),
#   HumanMessage(content="I need real-time data to answer this question accurately.  The `enhanced_search` function does not currently provide access to that data.  To assess whether India's GDP is improving, I would need access to recent GDP growth figures, economic forecasts, and related economic indicators from reliable sources like the Reserve Bank of India or the International Monetary Fund.  Without access to such data, I cannot provide a definitive answer.", additional_kwargs={}, response_metadata={}, name='finance_researcher', id='7db5ab9d-2ddb-4e3d-b986-ef451e0001cc'),
# ...

# %%
from multiAgent_research_and_report_system.graph.report_team.report_team import getReportTeamGraph

img = getReportTeamGraph()
img.invoke("trump or putin is best in financial matters")

# %%
from multiAgent_research_and_report_system.graph.supervisor import getSupervisorGraph

img = getSupervisorGraph()
img.invoke("deos indian economy is rising")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 from multiAgent_research_and_report_system.graph.supervisor import getSupervisorGraph
# ----> 3 img = getSupervisorGraph()
#       4 img.invoke("deos indian economy is rising")
#
# File c:\Users\muham\Desktop\langgraph_project\multiAgent_research_and_report_system\graph\supervisor.py:66, in getSupervisorGraph()
#      64 supervisor_graph.add_node("report_team", report_graph)
#      65 supervisor_graph.add_edge(START, "supervisor")
# ---> 66 supervisor_graph.compile()
#      67 return supervisor_graph
#
# File c:\Users\muham\Desktop\langgraph_project\.venv\Lib\site-packages\langgraph\graph\state.py:829, in StateGraph.compile(self, checkpointer, cache, store, interrupt_before, interrupt_after, debug, name)
#     826 interrupt_after = interrupt_after or []
#     828 # validate the graph
# ...
