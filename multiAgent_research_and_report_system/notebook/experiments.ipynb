# %%
import os
import sys
# sys.path.append(os.path.dirname(os.path.dirname("..")))
# os.path.dirname(os.path.dirname(os.path.join("..")))
path  = os.path.dirname(os.path.dirname(os.path.join(os.path.abspath(os.path.curdir))))
path
sys.path.append(path)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from graph.research_team.research_team import getResearchTeamGraph
#       3 getResearchTeamGraph()
#
# File c:\Users\muham\Desktop\langgraph_project\multiAgent_research_and_report_system\graph\research_team\research_team.py:1
# ----> 1 from multiAgent_research_and_report_system.src.supervisor import make_supervisor_node
#       2 from multiAgent_research_and_report_system.utils.model_loader import model_loader
#       3 from finance_research_node import finance_research_node
#
# ModuleNotFoundError: No module named 'multiAgent_research_and_report_system'

# %%
from graph.research_team.research_team import getResearchTeamGraph

img = getResearchTeamGraph()
img
# The 'img' variable is a CompiledStateGraph object, not a matplotlib figure.
# If you want to save a visualization of the graph, you need to use its visualization method.
# For LangGraph, you can use .get_graph().draw() if using networkx, or .draw() if available.

# Example using networkx and matplotlib:
# import matplotlib.pyplot as plt

# # graph = img.get_graph()  # get the underlying networkx graph
# plt.figure(figsize=(10, 8))
# plt.draw(img, with_labels=True)
# plt.savefig(os.path.join(path, "research_team_graph.png"), format="png")
# plt.close()

# %%
from graph.report_team.report_team import getReportTeamGraph

img = getReportTeamGraph()
img

# %%
from graph.supervisor import getSupervisorGraph

img = getSupervisorGraph()
img
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 3
#       1 from graph.supervisor import getSupervisorGraph
# ----> 3 img = getSupervisorGraph()
#       4 img
#
# File c:\Users\muham\Desktop\langgraph_project\multiAgent_research_and_report_system\graph\supervisor.py:25, in getSupervisorGraph()
#      23 supervisor_graph.add_node("report_team", report_graph)
#      24 supervisor_graph.add_edge(START, "supervisor")
# ---> 25 supervisor_graph.compile()
#      26 return supervisor_graph
#
# File c:\Users\muham\Desktop\langgraph_project\.venv\Lib\site-packages\langgraph\graph\state.py:829, in StateGraph.compile(self, checkpointer, cache, store, interrupt_before, interrupt_after, debug, name)
#     826 interrupt_after = interrupt_after or []
#     828 # validate the graph
# --> 829 self.validate(
#     830     interrupt=(
# ...
